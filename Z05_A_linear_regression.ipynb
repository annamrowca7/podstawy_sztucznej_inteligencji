# %% [markdown]
# # Regresja liniowa

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k');
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.
# My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
M1 = np.vstack( (np.ones_like(x), x) ).T
p1 = np.linalg.lstsq(M1, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_1 = lambda x: p1[0][1] * x +p1[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_1(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_2 = lambda x: p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_2(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M3 = np.vstack( (np.ones_like(x), x, x**2, x**3) ).T
p3 = np.linalg.lstsq(M3, y, rcond=None)
f_lr_3 = lambda x:p3[0][3]*pow(x,3)+p3[0][2]*pow(x,2) + p3[0][1] * x + p3[0][0] 
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_3(x_tr)
Res5 = sm.OLS(y, M3).fit()
print(Res5.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.990
# Dependent Variable: y                AIC:                279.8390
# Date:               2022-03-25 14:40 BIC:                290.2597
# No. Observations:   100              Log-Likelihood:     -135.92
# Df Model:           3                F-statistic:        3371.
# Df Residuals:       96               Prob (F-statistic): 4.12e-97
# R-squared:          0.991            Scale:              0.92435
# ------------------------------------------------------------------
#            Coef.    Std.Err.     t      P>|t|    [0.025    0.975]
# ------------------------------------------------------------------
# const      -3.3086    0.4174   -7.9258  0.0000   -4.1372   -2.4800
# x1         26.0627    1.1388   22.8870  0.0000   23.8022   28.3231
# x2        -25.9623    0.8413  -30.8593  0.0000  -27.6323  -24.2923
# x3          7.2297    0.1774   40.7581  0.0000    6.8776    7.5818
# -----------------------------------------------------------------
# Omnibus:              5.792        Durbin-Watson:           1.871
# Prob(Omnibus):        0.055        Jarque-Bera (JB):        5.187
# Skew:                 0.480        Prob(JB):                0.075
# Kurtosis:             2.432        Condition No.:           190
# =================================================================

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M5 = np.vstack( (np.ones_like(x), x, x**2, x**3,x**4) ).T
p5 = np.linalg.lstsq(M5, y, rcond=None)
f_lr_4 = lambda x: p5[0][4]*pow(x,4)+p5[0][3]*pow(x,3)+p5[0][2]*pow(x,2) + p5[0][1] * x + p5[0][0] 
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_4(x_tr)
Res5 = sm.OLS(y, M5).fit()
print(Res5.summary2())
# Out:
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     1.000
# Dependent Variable: y                AIC:                -23.1280
# Date:               2022-03-25 14:39 BIC:                -10.1021
# No. Observations:   100              Log-Likelihood:     16.564
# Df Model:           4                F-statistic:        5.328e+04
# Df Residuals:       95               Prob (F-statistic): 3.22e-158
# R-squared:          1.000            Scale:              0.044252
# --------------------------------------------------------------------
#            Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const     -0.7464     0.1085    -6.8776   0.0000   -0.9619   -0.5310
# x1         9.0755     0.4617    19.6580   0.0000    8.1590    9.9920
# x2        -0.8317     0.6037    -1.3776   0.1716   -2.0303    0.3668
# x3        -5.5792     0.2956   -18.8727   0.0000   -6.1660   -4.9923
# x4         2.0958     0.0480    43.7069   0.0000    2.0006    2.1910
# ------------------------------------------------------------------
# Omnibus:              0.751         Durbin-Watson:           1.715
# Prob(Omnibus):        0.687         Jarque-Bera (JB):        0.477
# Skew:                 -0.164        Prob(JB):                0.788
# Kurtosis:             3.084         Condition No.:           1296
# ==================================================================
# * The condition number is large (1e+03). This might indicate
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + a_5 \cdot x^5 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M5 = np.vstack( (np.ones_like(x), x, x**2, x**3,x**4,x**5) ).T
p5 = np.linalg.lstsq(M5, y, rcond=None)
f_lr_5 = lambda x:p5[0][5]*pow(x,5)+ p5[0][4]*pow(x,4)+p5[0][3]*pow(x,3)+p5[0][2]*pow(x,2) + p5[0][1] * x + p5[0][0] 
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_5(x_tr)
Res5 = sm.OLS(y, M5).fit()
print(Res5.summary2())
# Out:
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     1.000
# Dependent Variable: y                AIC:                -22.0311
# Date:               2022-03-25 14:38 BIC:                -6.4001
# No. Observations:   100              Log-Likelihood:     17.016
# Df Model:           5                F-statistic:        4.256e+04
# Df Residuals:       94               Prob (F-statistic): 5.18e-156
# R-squared:          1.000            Scale:              0.044320
# --------------------------------------------------------------------
#             Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const      -0.6989     0.1202   -5.8153   0.0000   -0.9376   -0.4603
# x1          8.5085     0.7684   11.0728   0.0000    6.9828   10.0342
# x2          0.5453     1.6089    0.3389   0.7354   -2.6492    3.7397
# x3         -6.8081     1.3633   -4.9938   0.0000   -9.5150   -4.1012
# x4          2.5529     0.4973    5.1339   0.0000    1.5656    3.5402
# x5         -0.0601     0.0651   -0.9235   0.3581   -0.1894    0.0692
# ------------------------------------------------------------------
# Omnibus:              0.691         Durbin-Watson:           1.751
# Prob(Omnibus):        0.708         Jarque-Bera (JB):        0.555
# Skew:                 -0.182        Prob(JB):                0.758
# Kurtosis:             2.977         Condition No.:           10028
# ==================================================================
# * The condition number is large (1e+04). This might indicate
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.
#
# ## Która z krzywych jest najleprza?

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
import statsmodels.api as sm
Res1 = sm.OLS(y, M1).fit()
Res2 = sm.OLS(y, M2).fit()

# %%
print(Res1.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.511
# Dependent Variable: y                AIC:                669.9226
# Date:               2022-03-25 14:26 BIC:                675.1330
# No. Observations:   100              Log-Likelihood:     -332.96
# Df Model:           1                F-statistic:        104.5
# Df Residuals:       98               Prob (F-statistic): 3.99e-17
# R-squared:          0.516            Scale:              46.598
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# -------------------------------------------------------------------
# const     -5.1103     1.4529   -3.5174   0.0007   -7.9934   -2.2271
# x1         7.9866     0.7813   10.2221   0.0000    6.4361    9.5371
# -----------------------------------------------------------------
# Omnibus:              16.001       Durbin-Watson:          1.995
# Prob(Omnibus):        0.000        Jarque-Bera (JB):       18.065
# Skew:                 0.977        Prob(JB):               0.000
# Kurtosis:             3.722        Condition No.:          5
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.824
# Dependent Variable: y                AIC:                568.5531
# Date:               2022-03-25 14:26 BIC:                576.3686
# No. Observations:   100              Log-Likelihood:     -281.28
# Df Model:           2                F-statistic:        233.2
# Df Residuals:       97               Prob (F-statistic): 8.73e-38
# R-squared:          0.828            Scale:              16.745
# ------------------------------------------------------------------
#             Coef.    Std.Err.     t     P>|t|    [0.025    0.975]
# ------------------------------------------------------------------
# const        8.0644    1.3215   6.1025  0.0000    5.4416   10.6872
# x1         -16.5866    1.9121  -8.6747  0.0000  -20.3815  -12.7917
# x2           7.8552    0.5926  13.2555  0.0000    6.6790    9.0313
# -----------------------------------------------------------------
# Omnibus:              3.708        Durbin-Watson:           1.959
# Prob(Omnibus):        0.157        Jarque-Bera (JB):        2.258
# Skew:                 0.136        Prob(JB):                0.323
# Kurtosis:             2.316        Condition No.:           28
# =================================================================

# %% [markdown]
# # Zadanie
# Analogiczne wyniki możemy izusklać za pomocą prostego kodu.

# %%
import statsmodels.formula.api as smf
# Turn the data into a pandas DataFrame, so that we
# can address them in the formulas with their name
df = pd.DataFrame({'x':x, 'y':y})

# Fit the models, and show the results
Res1F = smf.ols('y~x', df).fit()
Res2F = smf.ols('y ~ x+I(x**2)', df).fit()

# %%
print(Res1F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2F.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.516
# Model:                            OLS   Adj. R-squared:                  0.511
# Method:                 Least Squares   F-statistic:                     104.5
# Date:                Fri, 25 Mar 2022   Prob (F-statistic):           3.99e-17
# Time:                        14:26:36   Log-Likelihood:                -332.96
# No. Observations:                 100   AIC:                             669.9
# Df Residuals:                      98   BIC:                             675.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.1103      1.453     -3.517      0.001      -7.993      -2.227
# x              7.9866      0.781     10.222      0.000       6.436       9.537
# ==============================================================================
# Omnibus:                       16.001   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.065
# Skew:                           0.977   Prob(JB):                     0.000119
# Kurtosis:                       3.722   Cond. No.                         4.90
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.828
# Model:                            OLS   Adj. R-squared:                  0.824
# Method:                 Least Squares   F-statistic:                     233.2
# Date:                Fri, 25 Mar 2022   Prob (F-statistic):           8.73e-38
# Time:                        14:26:36   Log-Likelihood:                -281.28
# No. Observations:                 100   AIC:                             568.6
# Df Residuals:                      97   BIC:                             576.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      8.0644      1.322      6.102      0.000       5.442      10.687
# x            -16.5866      1.912     -8.675      0.000     -20.381     -12.792
# I(x ** 2)      7.8552      0.593     13.256      0.000       6.679       9.031
# ==============================================================================
# Omnibus:                        3.708   Durbin-Watson:                   1.959
# Prob(Omnibus):                  0.157   Jarque-Bera (JB):                2.258
# Skew:                           0.136   Prob(JB):                        0.323
# Kurtosis:                       2.316   Cond. No.                         27.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
